# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/Stock_NeurIPS2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
print(TRAIN_START_DATE)
# from config.py, TRAIN_END_DATE is a string
print(TRAIN_END_DATE)
# Out:
# 2014-01-06
# 2020-07-31

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-31'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (94331, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.762747  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  44.219181    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.418567   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941086    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  31.729946    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3229, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2009-01-02  AAPL   3.067143   3.251429   3.041429   2.762747  746015200.0
# 1  2009-01-02  AMGN  58.590000  59.080002  57.750000  44.219181    6547900.0
# 2  2009-01-02   AXP  18.570000  19.520000  18.400000  15.418567   10955700.0
# 3  2009-01-02    BA  42.799999  45.560001  42.779999  33.941086    7010200.0
# 4  2009-01-02   CAT  44.910000  46.980000  44.709999  31.729946    7117200.0
# 5  2009-01-02   CRM   8.025000   8.550000   7.912500   8.505000    4069200.0
# 6  2009-01-02  CSCO  16.410000  17.000000  16.250000  12.043803   40980600.0
# 7  2009-01-02   CVX  74.230003  77.300003  73.580002  44.063297   13695900.0
# 8  2009-01-02   DIS  22.760000  24.030001  22.500000  20.597496    9796600.0
# 9  2009-01-02    GS  84.019997  87.620003  82.190002  70.205002   14088500.0
#
#    day  macd   boll_ub  boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0      2.762747
# 1  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0     44.219181
# 2  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0     15.418567
# 3  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0     33.941086
# 4  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0     31.729946
# 5  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0      8.505000
# 6  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0     12.043803
# 7  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0     44.063297
# 8  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0     20.597496
# 9  4.0   0.0  2.985942  2.65615   100.0  66.666667  100.0     70.205002
#
#    close_60_sma        vix  turbulence
# 0      2.762747  39.189999         0.0
# 1     44.219181  39.189999         0.0
# 2     15.418567  39.189999         0.0
# 3     33.941086  39.189999         0.0
# 4     31.729946  39.189999         0.0
# 5      8.505000  39.189999         0.0
# 6     12.043803  39.189999         0.0
# 7     44.063297  39.189999         0.0
# 8     20.597496  39.189999         0.0
# 9     70.205002  39.189999         0.0

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 83897
# 9744

# %%
TRAIN_START_DATE
# Out:
# '2009-01-01'

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  285.857208
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  189.975357
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   48.926266
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   38.577278
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  115.618233
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019347  301.898608  269.441901  52.413040 -25.890875
# 2892   9040100.0  1.0  1.044595  197.956666  184.302283  53.021022 -51.589653
# 2892  17414800.0  1.0 -0.424526   52.365981   47.326286  48.097021 -51.128503
# 2892   4782100.0  1.0 -0.082999   42.108880   36.058569  48.830188 -14.542076
# 2892   6836400.0  1.0 -0.882725  118.955690  113.018227  48.159685 -69.952643
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    286.099495    279.127067  30.43   12.918668
# 2892  2.013358    190.720192    180.952010  30.43   12.918668
# 2892  8.508886     49.543358     49.982885  30.43   12.918668
# 2892  1.500723     38.675564     38.477854  30.43   12.918668
# 2892  3.847271    117.276859    119.204112  30.43   12.918668

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.631195
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  238.313553
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.394165
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  119.020714
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.005436   92.417428   79.936125  62.807103  107.496581
# 0    6575800.0  2.0  3.608526  230.616458  198.678626  61.279641  271.208747
# 0    3301000.0  2.0 -0.386237  109.593884   87.099641  48.504818  -66.313222
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.255426  128.858551  111.820864  52.865419   35.668240
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.678528     77.481208  28.620001   53.068014
# 0  46.806139    213.212108    214.276889  28.620001   53.068014
# 0   3.142448     96.513645     90.013764  28.620001   53.068014
# 0  15.932920    176.472335    155.614168  28.620001   53.068014
# 0  14.457404    117.798661    112.110444  28.620001   53.068014

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = True

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                                tb_log_name='ppo',
                                total_timesteps=50000) if if_using_ppo else None
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 135        |
# |    iterations      | 1          |
# |    time_elapsed    | 15         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.39338413 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015474166 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00805     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.9         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0311     |
# |    reward               | 0.627274    |
# |    std                  | 1           |
# |    value_loss           | 14.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 3          |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01650102 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.00112   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 23.8       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0229    |
# |    reward               | -1.6216046 |
# |    std                  | 1          |
# |    value_loss           | 69.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 4           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019185849 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00273     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0192     |
# |    reward               | 1.7701646   |
# |    std                  | 1           |
# |    value_loss           | 43.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 5           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015407906 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.0114      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.93        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | 2.885772    |
# |    std                  | 1.01        |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 6           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015880257 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.000121   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0209     |
# |    reward               | 2.447985    |
# |    std                  | 1.01        |
# |    value_loss           | 51.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 7          |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.02569322 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.4      |
# |    explained_variance   | -0.00122   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 12.6       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0202    |
# |    reward               | 0.6537581  |
# |    std                  | 1.01       |
# |    value_loss           | 41.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 8           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020601247 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0339     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0178     |
# |    reward               | 0.5387462   |
# |    std                  | 1.01        |
# |    value_loss           | 29.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 9           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018270291 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00673     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0224     |
# |    reward               | 0.5806635   |
# |    std                  | 1.01        |
# |    value_loss           | 32.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 10          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.022037383 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.00986    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 43.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0159     |
# |    reward               | 0.43544334  |
# |    std                  | 1.01        |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 11          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.025750838 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.00736    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0113     |
# |    reward               | 0.9639663   |
# |    std                  | 1.02        |
# |    value_loss           | 66.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 12         |
# |    time_elapsed         | 184        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02217257 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.6      |
# |    explained_variance   | -0.00375   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 8.14       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0232    |
# |    reward               | -0.3170649 |
# |    std                  | 1.02       |
# |    value_loss           | 16.8       |
# ----------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3088668.61
# total_reward: 2088668.61
# total_cost: 316774.07
# total_trades: 79134
# Sharpe: 0.673
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 13          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.02433439  |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0.0126      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 39.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | -0.38895556 |
# |    std                  | 1.02        |
# |    value_loss           | 51.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 14          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020739516 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0188      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0172     |
# |    reward               | -1.2240152  |
# |    std                  | 1.02        |
# |    value_loss           | 35.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 15          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.015805181 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.00972    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0145     |
# |    reward               | 4.414375    |
# |    std                  | 1.02        |
# |    value_loss           | 34.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 132          |
# |    iterations           | 16           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.01583522   |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.9        |
# |    explained_variance   | -0.00437     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 25.3         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0131      |
# |    reward               | -0.073363446 |
# |    std                  | 1.03         |
# |    value_loss           | 79.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 17          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.023752533 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0201     |
# |    reward               | 1.020861    |
# |    std                  | 1.03        |
# |    value_loss           | 66.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 132          |
# |    iterations           | 18           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.033520367  |
# |    clip_fraction        | 0.303        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.9        |
# |    explained_variance   | -0.0158      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 20.4         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0101      |
# |    reward               | -0.107107155 |
# |    std                  | 1.03         |
# |    value_loss           | 57.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 19          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023848372 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.0803      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.81        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0141     |
# |    reward               | -0.08733902 |
# |    std                  | 1.03        |
# |    value_loss           | 8.38        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 20          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.02314149  |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.0446      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.5        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0162     |
# |    reward               | -0.47859153 |
# |    std                  | 1.03        |
# |    value_loss           | 31.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 21         |
# |    time_elapsed         | 324        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02922352 |
# |    clip_fraction        | 0.328      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.2      |
# |    explained_variance   | 0.00437    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 43.5       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0116    |
# |    reward               | -7.890103  |
# |    std                  | 1.04       |
# |    value_loss           | 65.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 22          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.033524763 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | -0.0206     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.8        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0165     |
# |    reward               | 1.9684911   |
# |    std                  | 1.04        |
# |    value_loss           | 23.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 23         |
# |    time_elapsed         | 355        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02564977 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.3      |
# |    explained_variance   | 0.0208     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 10.1       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.019     |
# |    reward               | 0.26479405 |
# |    std                  | 1.04       |
# |    value_loss           | 49.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 24          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.020794027 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | -0.0145     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 56.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.014      |
# |    reward               | 8.547358    |
# |    std                  | 1.04        |
# |    value_loss           | 74.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 25          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.034978665 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.0182      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 45.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0139     |
# |    reward               | -1.2999961  |
# |    std                  | 1.04        |
# |    value_loss           | 63          |
# -----------------------------------------

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.631195
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  238.313553
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.394165
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  119.020714
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.005436   92.417428   79.936125  62.807103  107.496581
# 0    6575800.0  2.0  3.608526  230.616458  198.678626  61.279641  271.208747
# 0    3301000.0  2.0 -0.386237  109.593884   87.099641  48.504818  -66.313222
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.255426  128.858551  111.820864  52.865419   35.668240
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.678528     77.481208  28.620001   53.068014
# 0  46.806139    213.212108    214.276889  28.620001   53.068014
# 0   3.142448     96.513645     90.013764  28.620001   53.068014
# 0  15.932920    176.472335    155.614168  28.620001   53.068014
# 0  14.457404    117.798661    112.110444  28.620001   53.068014

# %%
trained_moedl = trained_ppo
df_account_value, df_actions = DRLAgent.DRL_prediction(model=trained_moedl, 
                                                       environment = e_trade_gym)
# Out:
# hit end!

# %%
train_last_day = data_split(processed_full, '2020-06-29',TRAIN_END_DATE)
e_trade_gym = StockTradingEnv(df = train_last_day, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(model=trained_moedl, 
                                                       environment = e_trade_gym)
# Out:
# hit end!

# %%
df_actions.to_latex('/Users/cheng/Google Drive/PhD/Research/Tactical asset allocation/table/rl_action_last_day.tex')

# %%
train_last_day = train_last_day.set_index('date')

# %%
train_last_day_price = train_last_day.loc['2020-06-29'].reset_index().set_index('tic')['close']

# %%
total_invest_value = df_actions @ train_last_day_price

# %%
w_rl = (df_actions * train_last_day_price).T / total_invest_value.values

# %%
w_rl.T.to_latex('/Users/cheng/Google Drive/PhD/Research/Tactical asset allocation/table/rl_portfolio_last_day.tex')

# %%
total_invest_value
# Out:
# date
# 2020-06-29    24020.19088
# dtype: float64

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.321260
# Cumulative returns     0.449832
# Annual volatility      0.139273
# Sharpe ratio           2.076922
# Calmar ratio           3.652024
# Stability              0.949086
# Max drawdown          -0.087968
# Omega ratio            1.430991
# Sortino ratio          3.071540
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.102895
# Daily value at risk   -0.016399
# dtype: float64
# /Users/cheng/opt/anaconda3/envs/tactical_asset_allocation/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
perf_stats_all.to_latex()
# Out:
#                             0
# Annual return        0.321260
# Cumulative returns   0.449832
# Annual volatility    0.139273
# Sharpe ratio         2.076922
# Calmar ratio         3.652024
# Stability            0.949086
# Max drawdown        -0.087968
# Omega ratio          1.430991
# Sortino ratio        3.071540
# Skew                      NaN
# Kurtosis                  NaN
# Tail ratio           1.102895
# Daily value at risk -0.016399

# %%
ret_df = df_account_value.set_index('date').pct_change()
ret_df.index = pd.to_datetime(ret_df.index)
ret_cum_df = (1 + ret_df).cumprod() - 1

# %%
np.sqrt(252) * ret_df.std()
# Out:
# account_value    0.139273
# dtype: float64

# %%
(ret_df).mean() * 252
# Out:
# account_value    0.289259
# dtype: float64

# %%
np.sqrt(252) * ret_df.mean() / ret_df.std()
# Out:
# account_value    2.076922
# dtype: float64

# %%
fig = plt.figure(figsize=(18,9))
plt.plot(ret_cum_df)
plt.ylabel('Cumulative return')
plt.tick_params(axis='x', rotation=45)
